# %%
#pip install deepface

# %%
#import the required modules
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace
# Out:
# WARNING:tensorflow:From C:\Users\dpcse\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# read image
#img = cv2.imread('happy.png')
#img = cv2.imread('angry_man.jpeg')
#img = cv2.imread('sad.jpeg')
#img = cv2.imread('fear.jpeg')
img = cv2.imread('surprise.jpeg')
#img = cv2.imread('neutral.jpeg')
#img = cv2.imread('disgust.jpeg')

# call imshow() using plt object
plt.imshow(img[:, :, : : -1])

# display that image
plt.show()

# %%
# storing the result
result = DeepFace.analyze(img,
                          actions = ['emotion'])

# print result
print(result)
# Out:
# [{'emotion': {'angry': np.float32(4.8714737e-06), 'disgust': np.float32(4.597607e-12), 'fear': np.float32(0.004206454), 'happy': np.float32(5.5679817e-07), 'sad': np.float32(1.8537683e-08), 'surprise': np.float32(99.99579), 'neutral': np.float32(4.7436412e-12)}, 'dominant_emotion': 'surprise', 'region': {'x': 104, 'y': 25, 'w': 66, 'h': 66, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.9}]

# %%
# DeepFace may return list or dict depending on version
if isinstance(result, list):
    result = result[0]

# Get dominant emotion
dominant_emotion = result["dominant_emotion"]
emotion_scores = result["emotion"]

print("Dominant Emotion:", dominant_emotion)
print("\nEmotion scores:")
for emo, score in emotion_scores.items():
    print(f"{emo}: {score:.2f}%")
# Out:
# Dominant Emotion: neutral
#
# Emotion scores:
# angry: 0.04%
# disgust: 0.00%
# fear: 0.01%
# happy: 0.01%
# sad: 0.30%
# surprise: 0.00%
# neutral: 99.64%
