# %%
#pip install deepface

# %%
#import the required modules
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace

# %%
# read image
#img = cv2.imread('happy.jpeg')
#img = cv2.imread('angry_man.jpeg')
#img = cv2.imread('sad.jpeg')
#img = cv2.imread('fear.jpeg')
#img = cv2.imread('surprise.jpeg')
#img = cv2.imread('neutral.jpeg')
img = cv2.imread('disgust.jpeg')
# call imshow() using plt object
plt.imshow(img[:, :, : : -1])

# display that image
plt.show()

# %%
# storing the result
result = DeepFace.analyze(img,
                          actions = ['emotion'])

# print result
print(result)
# Out:
# [{'emotion': {'angry': np.float32(15.558621), 'disgust': np.float32(4.2619988e-05), 'fear': np.float32(0.5745346), 'happy': np.float32(0.44103348), 'sad': np.float32(5.6538115), 'surprise': np.float32(0.037571087), 'neutral': np.float32(77.73438)}, 'dominant_emotion': 'neutral', 'region': {'x': 7, 'y': 3, 'w': 188, 'h': 188, 'left_eye': (136, 72), 'right_eye': (60, 76)}, 'face_confidence': 0.93}]

# %%
# DeepFace may return list or dict depending on version
if isinstance(result, list):
    result = result[0]

# Get dominant emotion
dominant_emotion = result["dominant_emotion"]
emotion_scores = result["emotion"]

print("Dominant Emotion:", dominant_emotion)
print("\nEmotion scores:")
for emo, score in emotion_scores.items():
    print(f"{emo}: {score:.2f}%")
# Out:
# Dominant Emotion: neutral
#
# Emotion scores:
# angry: 15.56%
# disgust: 0.00%
# fear: 0.57%
# happy: 0.44%
# sad: 5.65%
# surprise: 0.04%
# neutral: 77.73%
